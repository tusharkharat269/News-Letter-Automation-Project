# %%
import os

BASE_URL = "https://openrouter.ai/api/v1"
API_KEY = os.getenv("OPENROUTER_API_KEY")

# %%
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAI

# DeepSeek model hosted on OpenRouter
llm = ChatOpenAI(
    model="deepseek/deepseek-chat",  # or "deepseek/deepseek-r1"
    temperature=0.7,
    api_key= API_KEY,
    base_url=BASE_URL,
)

# response = llm.invoke("hi")
# print(response.content)

# %%
from langchain_tavily import TavilySearch

search_tool = TavilySearch(max_results=15,time_range="week")

# %%
from langchain.prompts import PromptTemplate

prompt = PromptTemplate(
    input_variables=["query", "results"],
    template="""
You are a Technology news research assistant.

Task:
- Analyze the following search results: {results}
- Select the TOP 5 most important technology news.

Query: {query}
---
Return only valid JSON list of 5 items.
"""
)

# %%
from typing import List
from pydantic import BaseModel, Field

class NewsResponse(BaseModel):
    headline: str = Field(description="headline of news in short")
    short_summary: str = Field(description="short summary of news in 2-3 lines")
    source_url: str = Field(description="URL of the news article")

class NewsList(BaseModel):
    items: List[NewsResponse] = Field(description="List of top 5 news articles")

# %%
from langchain.output_parsers import PydanticOutputParser

parser = PydanticOutputParser(pydantic_object=NewsResponse)

# %%
query = "latest AI technology updates"
# Run search
search_results = search_tool.invoke(query)

# Format prompt
final_prompt = prompt.format(query=query, results=search_results)

# %%
llm_with_op = llm.with_structured_output(NewsList)

# %%
# Generate LLM response
response = llm_with_op.invoke(final_prompt)
response
# Out:
# NewsList(items=[NewsResponse(headline='AI News & Articles - Artificial Intelligence Updates', short_summary='The latest advances in artificial intelligence and machine learning, generative AI, ChatGPT, LLMs, deepfakes, and more.', source_url='https://spectrum.ieee.org/topic/artificial-intelligence/'), NewsResponse(headline='AI News', short_summary='AI News delivers the latest breakthroughs in artificial intelligence, machine learning, deep learning, brain computer interface, robotics, and other future', source_url='https://www.youtube.com/@AINewsOfficial'), NewsResponse(headline='AI News | Latest AI News, Analysis & Events', short_summary="Malaysia launches Ryt Bank, its first AI-powered bank · Google's Veo 3 AI video creation tools are now widely available· AI is rewriting the rules of the", source_url='https://www.artificialintelligence-news.com/'), NewsResponse(headline='The latest AI news we announced in July', short_summary="Here's a recap of some of our biggest AI updates from July, including AI Mode tailored for back-to-school, new creative tools to transform your old Google", source_url='https://blog.google/technology/ai/google-ai-updates-july-2025/'), NewsResponse(headline='Artificial Intelligence - Latest AI News and Analysis', short_summary="OpenAI Launches Video Generator App to Rival TikTok and YouTube. The company's new social media app allows users to create short videos with audio from text", source_url='https://www.wsj.com/tech/ai?gaa_at=eafs&gaa_n=ASWzDAiCXcetMKkh2QyoY5ttX8hWdkCT1XK0pFyGHQqW5eprN1MeBUfEqdCK&gaa_ts=68dd3493&gaa_sig=CHgUleLMJd3gyBNl487u4ovN27SHhnqkb9vHc2L5KgTWTIVJbLdtnaTql7ftwZ70y9hh69OSqtc7vMaSpprE3Q==')])

# %%
# Or as Python dict
json_dict = response.model_dump()
json_dict
# Out:
# {'items': [{'headline': 'AI News & Articles - Artificial Intelligence Updates',
#    'short_summary': 'The latest advances in artificial intelligence and machine learning, generative AI, ChatGPT, LLMs, deepfakes, and more.',
#    'source_url': 'https://spectrum.ieee.org/topic/artificial-intelligence/'},
#   {'headline': 'AI News',
#    'short_summary': 'AI News delivers the latest breakthroughs in artificial intelligence, machine learning, deep learning, brain computer interface, robotics, and other future',
#    'source_url': 'https://www.youtube.com/@AINewsOfficial'},
#   {'headline': 'AI News | Latest AI News, Analysis & Events',
#    'short_summary': "Malaysia launches Ryt Bank, its first AI-powered bank · Google's Veo 3 AI video creation tools are now widely available· AI is rewriting the rules of the",
#    'source_url': 'https://www.artificialintelligence-news.com/'},
#   {'headline': 'The latest AI news we announced in July',
#    'short_summary': "Here's a recap of some of our biggest AI updates from July, including AI Mode tailored for back-to-school, new creative tools to transform your old Google",
#    'source_url': 'https://blog.google/technology/ai/google-ai-updates-july-2025/'},
#   {'headline': 'Artificial Intelligence - Latest AI News and Analysis',
#    'short_summary': "OpenAI Launches Video Generator App to Rival TikTok and YouTube. The company's new social media app allows users to create short videos with audio from text",
#    'source_url': 'https://www.wsj.com/tech/ai?gaa_at=eafs&gaa_n=ASWzDAiCXcetMKkh2QyoY5ttX8hWdkCT1XK0pFyGHQqW5eprN1MeBUfEqdCK&gaa_ts=68dd3493&gaa_sig=CHgUleLMJd3gyBNl487u4ovN27SHhnqkb9vHc2L5KgTWTIVJbLdtnaTql7ftwZ70y9hh69OSqtc7vMaSpprE3Q=='}]}

# %%
import json

print(json.dumps(json_dict,indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import json
# ----> 3 print(json.dump(json_dict,indent=2))
#
# NameError: name 'json_dict' is not defined

# %%
from langchain_anthropic import AnthropicLLM

model = AnthropicLLM()
# Out:
# e:\Github Repositries\News-Letter-Automation\myenv\lib\site-packages\pydantic\main.py:253: UserWarning: This Anthropic LLM is deprecated. Please use `from langchain_anthropic import ChatAnthropic` instead
#   validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
